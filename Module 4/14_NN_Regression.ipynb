# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/MSE_Spring_2026/blob/main/Module%204/14_NN_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tutorial notebook for the Spring 2026 course MSE510/420
# - Instructor Sergei V. Kalinin

# %% [markdown]
# # Simple NN regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Let's create a simple function and calculate both the ground truth answer and create some data.

# %%
# Define the function parameters
a, b, c = 1, 0.2, 3

# Generate noisy data
x_data = np.linspace(0, 5, 125)
noise = np.random.normal(0, 0.005, size=x_data.shape)
y_truth = a * x_data + b * x_data**2 + c * np.sin(3*x_data)
y_data = y_truth + noise

# Plotting the noisy data
plt.scatter(x_data, y_data, label='Noisy Data')
plt.plot(x_data, y_truth)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Noisy Dataset')
plt.show()

# %% [markdown]
# Now, let's define a simple NN model

# %%
# Model definition
model = Sequential([
    Dense(32, activation='tanh', input_dim=1),
    Dense(32, activation='tanh'),
    Dense(128, activation='relu'),
    Dense(8, activation='linear'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Reshape the data and train the model

# %%
# Reshape data for training
X_train = x_data.reshape(-1, 1)
Y_train = y_data.reshape(-1, 1)

# Train the model
model.fit(X_train, Y_train, epochs=1000, verbose=1)
# Out:
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 983ms/step - loss: 26.6033
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.4179
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.9673
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.2464
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0074
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3377
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3373
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9681
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1704
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4416
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2939
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8161
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0297
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9240
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7682
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5631
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8187
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5627
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7889
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1156
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0760
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1821
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0398
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3781
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4319
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6538
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7230
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6976
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9247
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0939
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7089
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6385
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2281
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2384
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0120
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4487
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8856
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5489
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4741
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9742
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0764
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1095
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9480
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6085
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3834
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7714
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3776
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7308
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3824
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7151
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6963
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5545
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4031
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6801
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6366
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5204
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4594
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6657
# Epoch 59/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3863
# Epoch 60/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5338
# Epoch 61/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5447
# Epoch 62/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2227
# Epoch 63/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5284
# Epoch 64/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4159
# Epoch 65/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4065
# Epoch 66/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4277
# Epoch 67/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2602
# Epoch 68/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4883
# Epoch 69/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5701
# Epoch 70/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1042
# Epoch 71/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1088
# Epoch 72/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5448
# Epoch 73/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4158
# Epoch 74/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2492
# Epoch 75/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2042
# Epoch 76/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0985
# Epoch 77/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4688
# Epoch 78/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6728
# Epoch 79/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3617
# Epoch 80/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5254
# Epoch 81/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4046
# Epoch 82/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4931
# Epoch 83/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2848
# Epoch 84/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2230
# Epoch 85/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5424
# Epoch 86/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3080
# Epoch 87/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4235
# Epoch 88/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4304
# Epoch 89/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9827
# Epoch 90/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1654
# Epoch 91/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5144
# Epoch 92/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2814
# Epoch 93/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1255
# Epoch 94/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4634
# Epoch 95/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6642
# Epoch 96/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2578
# Epoch 97/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9987
# Epoch 98/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5737
# Epoch 99/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1591
# Epoch 100/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5202
# Epoch 101/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1366
# Epoch 102/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2340
# Epoch 103/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5123
# Epoch 104/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4558
# Epoch 105/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2596
# Epoch 106/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5171
# Epoch 107/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2693
# Epoch 108/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3331
# Epoch 109/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1971
# Epoch 110/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4199
# Epoch 111/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4804
# Epoch 112/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5181
# Epoch 113/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5525
# Epoch 114/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1270
# Epoch 115/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4896
# Epoch 116/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9622
# Epoch 117/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0581
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2666
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0547
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4812
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5118
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3817
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0380
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2087
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0760
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4474
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3848
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5882
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0694
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2446
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2097
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1817
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2421
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1015
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4362
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4374
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0567
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8807
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3999
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0579
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1989
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3834
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5417
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1622
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1913
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2478
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9176
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1968
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1593
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6033
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0729
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0770
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1498
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5562
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7515
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1645
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1027
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2585
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0345
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2668
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4056
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2530
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2432
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9468
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7176
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1847
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1911
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8880
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1244
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0508
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7963
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3199
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0641
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0382
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6260
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1405
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7429
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7704
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8748
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3046
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2737
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1351
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0137
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9242
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6645
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0610
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9996
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9468
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1934
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1754
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0800
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9090
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4150
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8823
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1534
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6230
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9264
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0543
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0972
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2014
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7481
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8259
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8381
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6509
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7287
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6040
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9642
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2057
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1604
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9084
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0032
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7961
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6881
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6983
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2340
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9500
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9962
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2343
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2514
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2150
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2260
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1721
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1435
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1445
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1485
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1470
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1411
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1507
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1346
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1309
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1691
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1443
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1384
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1173
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1090
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1415
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1336
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1621
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1132
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1719
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1637
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1418
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1296
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1194
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1638
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1231
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1203
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1163
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1171
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1380
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1509
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1715
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1877
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1637
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2088
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1951
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2047
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1909
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1771
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2081
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1528
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1217
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1678
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1533
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1081
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1545
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1448
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1442
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1067

# %% [markdown]
# And see how this model behaves on the test data

# %%
# Generate test data
x_test = np.linspace(0, 5, 300)
y_test = model.predict(x_test)

# Plotting the predictions against the noisy data
plt.scatter(x_data, y_truth, label='Noisy Data')
plt.plot(x_test, y_test, color='red', label='NN Predictions')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Neural Network Predictions vs. Noisy Data')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step

# %%
model.*?

# %% [markdown]
# Experiment how the NN will behave if we change the numbe rof layers, neurons in the layers, and the activation fucntions.

# %% [markdown]
# # Ensemble NNs and uncertainties

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate synthetic data
a, b, c = 1, 0.2, 3
x_data = np.linspace(0, 5, 200)
noise = np.random.normal(0, 0.005, size=x_data.shape)
y_data = a * x_data + b * x_data**2 + c * np.sin(3*x_data) + noise

# Function to create a model
def create_model():
    model = Sequential([
        Dense(128, activation='relu', input_shape=(1,)),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# Create an ensemble of models
num_models = 10
models = [create_model() for _ in range(num_models)]

# Train each model in the ensemble
for i, model in enumerate(models):
    print("Model ", i)
    model.fit(x_data, y_data, epochs=500, verbose=0)

# Predict using the ensemble and calculate mean and uncertainty (standard deviation)
predictions = np.array([model.predict(x_data) for model in models])
mean_predictions = np.mean(predictions, axis=0)
uncertainty = np.std(predictions, axis=0)

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_data, y_data, color='gray', alpha=0.6, label='Data')
plt.plot(x_data, mean_predictions, color='red', label='Ensemble Mean Prediction')
plt.fill_between(x_data, (mean_predictions - uncertainty).flatten(), (mean_predictions + uncertainty).flatten(), color='red', alpha=0.2, label='Prediction Uncertainty')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ensemble Predictions with Uncertainty')
plt.legend()
plt.show()
# Out:
# Model  0
# Model  1
# Model  2
# Model  3
# Model  4
# Model  5
# Model  6
# Model  7
# Model  8
# Model  9
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step
# WARNING:tensorflow:5 out of the last 18 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c890fa36520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c890fa344a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step

# %% [markdown]
# # NN Regression in 2D

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a grid
x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(3*X) + np.sin(Y) + np.sin(X*Y)

# Visualize the original function
plt.figure(figsize=(6, 5))
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='viridis')
plt.colorbar(label='Function Value')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Original Function: $f(x, y) = \sin(x) + \sin(y) + \sin(xy)$')
plt.show()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-13324/938896330.py:16: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Original Function: $f(x, y) = \sin(x) + \sin(y) + \sin(xy)$')

# %%
# Sampling points
num_samples = 500
x_sample = np.random.uniform(0, 5, num_samples)
y_sample = np.random.uniform(0, 5, num_samples)
z_sample = np.sin(3*x_sample) + np.sin(y_sample) + np.sin(x_sample*y_sample) + np.random.normal(0, 0.1, num_samples)

# Visualizing sampled points
plt.scatter(x_sample, y_sample, c=z_sample, cmap='viridis')
plt.colorbar(label='Function Value')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sampled Points with Noise')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(2,)),
    Dense(4, activation='relu'),
    Dense(128, activation='relu'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Prepare data for training
train_data = np.vstack((x_sample, y_sample)).T
train_labels = z_sample

# Train the model
model.fit(train_data, train_labels, epochs=1000, verbose=0)

# %%
# Generate a prediction grid
x_test, y_test = np.meshgrid(np.linspace(0, 5, 100), np.linspace(0, 5, 100))
z_test = model.predict(np.hstack((x_test.reshape(-1, 1), y_test.reshape(-1, 1)))).reshape(100, 100)

# Visualizing NN fit results
plt.figure(figsize=(6, 5))
plt.imshow(z_test, extent=[0, 5, 0, 5], origin='lower', cmap='viridis')
plt.colorbar(label='Function Value')
plt.xlabel('x')
plt.ylabel('y')
plt.title('NN Fit to $f(x, y) = \sin(x) + \sin(y) + \sin(xy)$')
plt.show()

# %%
# Assuming the necessary imports, model definition, and training have been completed as described.

# Ground truth function evaluation on the grid
Z_ground_truth = np.sin(3*X) + np.sin(Y) + np.sin(X*Y)

# Predictions from the neural network
Z_predictions = model.predict(np.hstack((X.reshape(-1, 1), Y.reshape(-1, 1)))).reshape(100, 100)

# Calculating the error
Z_error = np.abs(Z_ground_truth - Z_predictions)

# Plotting ground truth, predictions, and error side by side
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Ground Truth
img0 = axs[0].imshow(Z_ground_truth, extent=[0, 5, 0, 5], origin='lower', cmap='viridis')
fig.colorbar(img0, ax=axs[0], fraction=0.046, pad=0.04)
axs[0].set_title('Ground Truth')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

# Predictions
img1 = axs[1].imshow(Z_predictions, extent=[0, 5, 0, 5], origin='lower', cmap='viridis')
fig.colorbar(img1, ax=axs[1], fraction=0.046, pad=0.04)
axs[1].set_title('NN Predictions')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

# Error
img2 = axs[2].imshow(Z_error, extent=[0, 5, 0, 5], origin='lower', cmap='hot')
fig.colorbar(img2, ax=axs[2], fraction=0.046, pad=0.04)
axs[2].set_title('Prediction Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
